# %%
# %matplotlib notebook
import sqs_nqs_tools as nqs
from sqs_nqs_tools.offline import access, adata, tof

# Plot options
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# Import required libraries
import numpy as np 
import pyqtgraph as pg

# Import karabo libraries
import karabo_bridge as kb
import karabo_data as kd
# Out:
# Welcome to sqs_nqs_tools version v0.2+45.gc4b62f8.dirty

# %%
def plot_ccd(shot):
    plt.figure()
    plt.imshow(shot, norm=LogNorm(), cmap = plt.get_cmap('inferno'))
    plt.colorbar()
    plt.show()

# %%
fname = 'pnCCD_detected_137324194.0_137324195.0_137324205.0_137324209.0_137324224.0__pnCCD.npy'
# background_pnCCD = np.load('/home/bjoerns/code/XFEL_SQS_NQS_Tools/scripts/bokeh_live/background_max_pnCCD.npy')
background_pnCCD = np.load('/home/bjoerns/code/XFEL_SQS_NQS_Tools/scripts/bokeh_live/output/'+fname)
# background_pnCCD = np.load('/home/bjoerns/code/XFEL_SQS_NQS_Tools/scripts/bokeh_live/output/tof_detected_136262193.0_pnCCD.npy')
# tof = np.load('/home/bjoerns/code/XFEL_SQS_NQS_Tools/scripts/bokeh_live/output/pnCCD_detected_135410477.0_135410845.0_135410877.0__tof.npy')
# tof=np.squeeze(np.squeeze(tof))
print(np.mean(background_pnCCD))
print(np.max(background_pnCCD))
print(np.min(background_pnCCD))
# background_pnCCD=np.squeeze(background_pnCCD)
# Out:
# 23.52555192760959
# 6470.752522372684
# -2337.5140437119426

# %%
background_pnCCD.shape
tof.shape
# Out:
# (3, 31000)

# %%
background_pnCCD[background_pnCCD<1]=1
for i in range(background_pnCCD.shape[0]):
    plot_ccd(np.squeeze(background_pnCCD[i,:,:]))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(np.squeeze(tof[2,:]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
